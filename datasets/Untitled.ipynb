# %%
import pandas as pd

# %% [markdown]
# # Akas Prep

# %%
data = pd.read_csv('title.akas.tsv', delimiter='\t')
# Out:
# /usr/local/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (7) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
data.head()
# Out:
#      titleId  ordering                      title region language  \
# 0  tt0000001         1                 Карменсіта     UA       \N
# 1  tt0000001         2                 Carmencita     DE       \N
# 2  tt0000001         3  Carmencita - spanyol tánc     HU       \N
# 3  tt0000001         4                 Καρμενσίτα     GR       \N
# 4  tt0000001         5                 Карменсита     RU       \N
#
#          types     attributes isOriginalTitle
# 0  imdbDisplay             \N               0
# 1           \N  literal title               0
# 2  imdbDisplay             \N               0
# 3  imdbDisplay             \N               0
# 4  imdbDisplay             \N               0

# %%
data[data['isOriginalTitle']==1].to_csv('title.akas.v2.tsv', index=False, na_rep=r'\N', sep='\t')

# %%
del data
# Out:
#           titleId  ordering                         title region language  \
# 0       tt0000001         7                    Carmencita     \N       \N
# 1       tt0000002         1        Le clown et ses chiens     \N       \N
# 2       tt0000003         6                Pauvre Pierrot     \N       \N
# 3       tt0000004         1                   Un bon bock     \N       \N
# 4       tt0000005        10              Blacksmith Scene     \N       \N
# ...           ...       ...                           ...    ...      ...
# 125264  tt9916362         4                      Akelarre     \N       \N
# 125265  tt9916428         2  Hong xing zhao yao Zhong guo     \N       \N
# 125266  tt9916460         2                     Pink Taxi     \N       \N
# 125267  tt9916678         2                    Acelerados     \N       \N
# 125268  tt9916720         5                     The Nun 2     \N       \N
#
#            types attributes  isOriginalTitle
# ...

# %%
name_basics = pd.read_csv('name.basics.tsv', delimiter='\t')
data.head()
# Out:
#       nconst      primaryName birthYear deathYear  \
# 0  nm0000001     Fred Astaire      1899      1987
# 1  nm0000002    Lauren Bacall      1924      2014
# 2  nm0000003  Brigitte Bardot      1934        \N
# 3  nm0000004     John Belushi      1949      1982
# 4  nm0000005   Ingmar Bergman      1918      2007
#
#                      primaryProfession  \
# 0       soundtrack,actor,miscellaneous
# 1                   actress,soundtrack
# 2  actress,soundtrack,music_department
# 3              actor,soundtrack,writer
# 4                writer,director,actor
#
#                             knownForTitles
# 0  tt0050419,tt0072308,tt0053137,tt0031983
# 1  tt0071877,tt0037382,tt0117057,tt0038355
# 2  tt0057345,tt0056404,tt0054452,tt0049189
# 3  tt0072562,tt0080455,tt0078723,tt0077975
# 4  tt0060827,tt0050976,tt0069467,tt0050986

# %%
title_basics = pd.read_csv('title.basics.tsv', delimiter='\t', na_values='\\N')
# Out:
# /usr/local/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (7) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
title_basics.head()
# Out:
#       tconst titleType            primaryTitle           originalTitle  \
# 0  tt0000001     short              Carmencita              Carmencita
# 1  tt0000002     short  Le clown et ses chiens  Le clown et ses chiens
# 2  tt0000003     short          Pauvre Pierrot          Pauvre Pierrot
# 3  tt0000004     short             Un bon bock             Un bon bock
# 4  tt0000005     short        Blacksmith Scene        Blacksmith Scene
#
#    isAdult  startYear  endYear runtimeMinutes                    genres
# 0      0.0     1894.0      NaN            1.0         Documentary,Short
# 1      0.0     1892.0      NaN            5.0           Animation,Short
# 2      0.0     1892.0      NaN            4.0  Animation,Comedy,Romance
# 3      0.0     1892.0      NaN           12.0           Animation,Short
# 4      0.0     1893.0      NaN            1.0              Comedy,Short

# %%
title_basics[(title_basics['startYear'] >= 2000) & (title_basics['endYear'] < 2010)]
# Out:
#             tconst     titleType                primaryTitle  \
# 150807   tt0155425      tvSeries              Black Scorpion
# 157730   tt0162828      tvSeries          The Tom Green Show
# 179362   tt0185906  tvMiniSeries            Band of Brothers
# 193709   tt0201374  tvMiniSeries       Anderssons älskarinna
# 202035   tt0210294  tvMiniSeries                  Snow Queen
# ...            ...           ...                         ...
# 7631601  tt9883340      tvSeries            Sevgili düsmanim
# 7638727  tt9898342      tvSeries       Whizz Whizz Bang Bang
# 7641562  tt9904342      tvSeries  Tales of the Seventh Fleet
# 7643545  tt9908496      tvSeries            Biblická pátrání
# 7646261  tt9914128      tvSeries               Party Animals
#
#                       originalTitle  isAdult  startYear  endYear  \
# 150807               Black Scorpion      0.0     2001.0   2001.0
# 157730           The Tom Green Show      0.0     2002.0   2002.0
# ...

# %%
principals = pd.read_csv('title.principals.tsv', delimiter='\t', na_values='\\N')

# %%
principals.head()
# Out:
#       tconst  ordering     nconst         category                      job  \
# 0  tt0000001         1  nm1588970             self                      NaN
# 1  tt0000001         2  nm0005690         director                      NaN
# 2  tt0000001         3  nm0374658  cinematographer  director of photography
# 3  tt0000002         1  nm0721526         director                      NaN
# 4  tt0000002         2  nm1335271         composer                      NaN
#
#   characters
# 0   ["Self"]
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN

# %%
principals[principals.category == 'actress']
# Out:
#              tconst  ordering      nconst category  job  \
# 24        tt0000009         1   nm0063086  actress  NaN
# 51        tt0000017         2   nm3692829  actress  NaN
# 83        tt0000032         1   nm3692479  actress  NaN
# 126       tt0000061         1   nm4007970  actress  NaN
# 143       tt0000075         1   nm0194945  actress  NaN
# ...             ...       ...         ...      ...  ...
# 43200206  tt9916856         4  nm10538647  actress  NaN
# 43200211  tt9916880        10   nm2676923  actress  NaN
# 43200213  tt9916880         2   nm0254176  actress  NaN
# 43200215  tt9916880         4  nm10535738  actress  NaN
# 43200220  tt9916880         9   nm1052583  actress  NaN
#
#                                                  characters
# 24                 ["Miss Geraldine Holbrook (Miss Jerry)"]
# 51                                             ["The girl"]
# 83                                           ["The dancer"]
# ...

# %%
principals.category.unique()
# Out:
# array(['self', 'director', 'cinematographer', 'composer', 'producer',
#        'editor', 'actor', 'actress', 'writer', 'production_designer',
#        'archive_footage', 'archive_sound'], dtype=object)

# %%
principals.job.unique()
# Out:
# array([nan, 'director of photography', 'producer', ...,
#        "based upon 'Star Trek Enterprise' created by",
#        'short story "Your Iron Lady"',
#        'original screenplay "Teorie tygra"'], dtype=object)
